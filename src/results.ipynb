# %% [markdown]
# # Sample project
# This project aims to ... <1 paragraph summary>

# %%
from load import fetch_and_cache
from process import flatten_businesses
from analyze import analyze_yelp_data

# %% [markdown]
# # Yelp Data example

# %%
raw = fetch_and_cache("restaurants", "Los Angeles, CA", limit=50, pages=1) # 50 restaurants
csv_path = flatten_businesses(raw)

analyze_yelp_data(csv_path, dataset_name="restaurants_Los_Angeles_CA", notebook_plot=True)
# Out:
# Saved correlation matrix to /Users/lauren/Desktop/final_project/results/restaurants_Los_Angeles_CA_correlations.csv
# Linear Regression: R²=0.609, MAE=0.083
# Random Forest: R²=0.823, MAE=0.087
# Saved feature importances to /Users/lauren/Desktop/final_project/results/restaurants_Los_Angeles_CA_feature_importance.csv
# Analysis complete. Results saved in: /Users/lauren/Desktop/final_project/results
#                         id                          name  rating  \
# 0   XgQ8riUvnMOBVfRG29NCEQ                    Anju House     4.4
# 1   z0zaCVA-p_5xTsyUZrmR0g                    Republique     4.2
# 3   fEY0zHaDMfIW3-N__joDKQ                        Bestia     4.3
# 4   yGsnyyZD4Zpns0ty50tq8A    Chubby Cattle Little Tokyo     4.9
# 5   RVbZaawgEGmto6TxOoVBdQ                 Running Goose     4.3
# 6   HuQtriV_ApipXfM8xax33w              Met Him At A Bar     4.4
# 7   TkFEKhsCixPWlShULKvMdQ                 Bottega Louie     4.1
# ...
